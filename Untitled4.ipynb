# %%
import time
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
from textblob import TextBlob
import matplotlib.pyplot as plt
import re

# %%
'# -- coding: utf-8 --'
# Out:
# '# -- coding: utf-8 --'

# %%
def calctime(a):
    return time.time()-a

# %%
positive=0
negative=0
compound=0

# %%
initime=time.time()

# %%
count=0
plt.ion()

# %%
import test

# %%
ckey='wWafyHPxYVi7isAUBjcBUkT29'
csecret='nBbnKPS1Gh5GI8gT4wqisISAPhwLXUOAu6yyEBiThs6sYGhTh7'
atoken='1007208665848283136-7RLNAE6vYFquAx5BcqmlSjSPaMuQMs'
asecret='mlW4Lc8ueZGFHUCCQYK2fOuQOFSK0BQaGqe1CrulxCpIL'

# %%
class listener(StreamListener):
    
    def on_data(self,data):
        global initime
        
        t=int(calctime(initime))
        
        all_data=json.loads(data)
        tweet=all_data["text"]
        tweet=" ".join(re.findall("[a-zA-Z]+",tweet))
        blob=TextBlob(tweet.strip())
        
        global positive
        global negative
        global compound
        global count
        
        count =count+1
        senti=0
        
        for sen in blob.sentences:
            senti=senti+sen.sentiment.polarity
            if sen.sentiment.polarity>=0:
                positive=positive+sen.sentiment.polarity
            else:
                negative=negative+sen.sentiment.polarity
            compound=compound+senti
            
        print(count)
        print(tweet.strip())
        print(senti)
        print(t)
        print(str(positive)+' '+str(negative)+' '+str(compound))
        
        plt.axis([0,70,-20,20])
        plt.xlabel('time')
        plt.ylabel('sentiment')
        plt.plot([t],[positive],'go',[t],[negative],'ro',[t],[compound],'bo')
        plt.show()
        plt.pause(0.0001)
        if count==200:
            return False
        else:
            return True
        def on_error(self,status):
            print(status)
auth=OAuthHandler(ckey,csecret)
auth.set_access_token(atoken,asecret)

searchTerm=input("enter keyword/tag to search tweet:")
NoOfTerms=int(input("enter number of terms"))

twitterStream=Stream(auth,listener(NoOfTerms))
twitterStream.filter(track=[searchTerm])
# Out:
# enter keyword/tag to search tweet:modi
# enter number of terms8
# 2
# RT bubipin PM MODI GOONS LOOTS DON T FIND DOCTOR MEDICAL PROFESSIONAL SERVICE LIKE HEART STENTS BYPASS CATARACT REDUCED COST TO HALF CH
# -0.022222222222222216
# 2535
# 0.0 -0.022222222222222216 -0.022222222222222216
# 3
# RT TimesNow Even in Iftar party they have nothing to discuss Trying to please Maharaja to score brownie points shows how shallow they a
# -0.3333333333333333
# 2535
# 0.0 -0.3555555555555555 -0.3555555555555555
# 4
# RT digvijaya Indians are having serious second thoughts about Modi s economics https t co sOHNTk Iyo via economictimes
# -0.16666666666666666
# 2535
# 0.0 -0.5222222222222221 -0.5222222222222221
# 5
# RT INCIndia https t co UfQMCSCmvz
# 0.0
# 2536
# 0.0 -0.5222222222222221 -0.5222222222222221
# 6
# RT TVMohandasPai The BIG LIE UPA II funded cronies from banks created L cr NPA PM Modi cleaning this up sending them to bankruptcy
# 0.0
# 2536
# ...
